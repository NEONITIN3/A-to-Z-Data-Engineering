# %% [markdown]
# # pandas ,numpy

# %%
import pandas as pd
import numpy as np


# Creating empty series
ser = pd.Series()

print(ser)

# simple array
data = np.array(['g', 'e', 'e', 'k', 's'])

ser = pd.Series(data)
print(ser)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       5 # Creating empty series
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print("hi"+"\n"+"nahi")
print("hello")
# Out:
# hi
# nahi
# hello

# %% [markdown]
# # Creating a DataFrame:

# %%
df = pd.DataFrame()
print(df)
 
# list of strings
lst = ['Geeks', 'For', 'Geeks', 'is', 
            'portal', 'for', 'Geeks']
   
# Calling DataFrame constructor on list
df = pd.DataFrame(lst)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
df = pd.read_csv("examplefile.csv")
df
# Out:
#               ban attribute_code attribute_sub_type   effective_datetime  \
# 0       127372547                             ENJOY  2020-08-19 00:00:00
# 1       121338331                             ENJOY  2020-08-19 00:00:00
# 2       121213295                             ENJOY  2020-08-19 00:00:00
# 3       125286931                             ENJOY  2020-08-19 00:00:00
# 4       120072633                             ENJOY  2020-08-19 00:00:00
# ...           ...            ...                ...                  ...
# 167400  128958184          EMAIL              ENJOY  2021-01-16 00:00:00
# 167401  124405499          EMAIL              ENJOY  2021-01-16 00:00:00
# 167402  122549065          EMAIL              ENJOY  2021-01-16 00:00:00
# 167403  149230264          EMAIL              ENJOY  2021-01-16 00:00:00
# 167404  148593895          EMAIL              ENJOY  2021-01-16 00:00:00
#
#        sys_creation_datetime sys_updatetime_datetime  operator_id  \
# ...

# %% [markdown]
# # Reading CSV file with custome delimeter

# %%
df = pd.read_csv('examplefile.csv',
                 sep=',',
                 engine='python')
  
# Print the Dataframe
df
# Out:
#               ban attribute_code attribute_sub_type   effective_datetime  \
# 0       127372547                             ENJOY  2020-08-19 00:00:00
# 1       121338331                             ENJOY  2020-08-19 00:00:00
# 2       121213295                             ENJOY  2020-08-19 00:00:00
# 3       125286931                             ENJOY  2020-08-19 00:00:00
# 4       120072633                             ENJOY  2020-08-19 00:00:00
# ...           ...            ...                ...                  ...
# 167400  128958184          EMAIL              ENJOY  2021-01-16 00:00:00
# 167401  124405499          EMAIL              ENJOY  2021-01-16 00:00:00
# 167402  122549065          EMAIL              ENJOY  2021-01-16 00:00:00
# 167403  149230264          EMAIL              ENJOY  2021-01-16 00:00:00
# 167404  148593895          EMAIL              ENJOY  2021-01-16 00:00:00
#
#        sys_creation_datetime sys_updatetime_datetime  operator_id  \
# ...

# %% [markdown]
# # Reading particular colomn in Data CSV file

# %%
df = pd.read_csv("examplefile.csv",
                header=0,
                usecols= ["effective_datetime","attribute_s_value","sys_creation_datetime"],
                nrows=5)
df
# Out:
#     effective_datetime sys_creation_datetime                 attribute_s_value
# 0  2020-08-19 00:00:00   2020-08-19 09:22:35           BECHURLEY@HOTMAIL.CO.UK
# 1  2020-08-19 00:00:00   2020-08-19 07:23:13  WENDYMCCORMACK960@GOOGLEMAIL.COM
# 2  2020-08-19 00:00:00   2020-08-19 08:13:57           RAYWILLETTS11@GMAIL.COM
# 3  2020-08-19 00:00:00   2020-08-19 08:19:58              SPOCKROT@YAHOO.CO.UK
# 4  2020-08-19 00:00:00   2020-08-19 08:25:12   JOHNATHAN@REGAL.FREESERVE.CO.UK

# %%
        var = 1
print(var)
# Out:
# 1

# %%
t=7.8
print(type(t))
# Out:
# <class 'float'>

# %%
l=['s',1,2,4]
print(id(l))
l= [1.2,45]+l
print(l)
print(id(l))
print(len(l))
# Out:
# 2026442406656
# [1.2, 45, 's', 1, 2, 4]
# 2026442564288
# 6

# %%
t = 1,
print(id(t))
print(len(t))
t =(12,121)+t
print(t)
print(id(t))
print(len(t))
# Out:
# 2026436705200
# 1
# (12, 121, 1)
# 2026442406272
# 3

# %%
t = '12','1'+t

# %%
p  y t h o n
-6-5-4-3-2-1
s="python"
print(s[-2::-2])
# Out:
# otp

# %%
print(22/7)   #it will give exact output
# Out:
# 3.142857142857143

# %%
print(22//7)   #floor value niche ka value
# Out:
# 3

# %%
print("PHP">"php") #its compare with charecter by charecter ASCII value
# Out:
# False

# %%
print("php">"pephj") 
# its true because its compare ASCII value charecter by char by char h>e ASCII
# Out:
# True
